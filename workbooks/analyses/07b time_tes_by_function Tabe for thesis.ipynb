# %%
import cPickle as pkl

# %%
all_time_tes_annotated = pkl.load(open("../../parameters/all_time_tes_annotated.df"))

# %% [markdown]
# We want to calculate a table of $\mu$ and $\sigma$ per functional category and time.

# %%
all_time_tes_annotated.head()
# Out:
#                 0       300       600       900      1200      1500      1800  \
# YBR177C  0.128333  0.133333       NaN  0.043333  0.055833  0.034167  0.031000
# YIL140W  0.098333  0.100000  0.040833  0.048333  0.048333  0.031667       NaN
# YLR268W  0.135000  0.110000  0.060333  0.054048  0.055333  0.036458  0.036970
# YJL155C  0.115000       NaN  0.038333  0.053333  0.043333  0.035000  0.025833
# YLR197W  0.143333  0.145000  0.071322  0.069624  0.075333  0.048251  0.048145
#
#              2100      2400      2700      3000      3300  \
# YBR177C  0.037500  0.091667  0.077500  0.123333  0.065000
# YIL140W       NaN  0.078333       NaN       NaN       NaN
# YLR268W  0.034167  0.088333  0.080556  0.120000  0.072222
# YJL155C  0.020000  0.078333  0.080000  0.100000  0.075000
# YLR197W  0.050645  0.105000  0.108512  0.139792  0.102849
#
#                                           Function
# YBR177C
# YIL140W
# YLR268W  SNARE interactions in vesicular transport
# YJL155C                    Carbohydrate metabolism
# YLR197W          Ribosome biogenesis in eukaryotes

# %%
all_time_tes_annotated.Function.value_counts(dropna=False)
# Out:
#                                                1859
# Other enzymes                                   122
# Amino acid metabolism                           116
# Chromosome-related                              112
# Ribosome                                        110
# Cofactor biosynthesis                            82
# Lipid and steroid metabolism                     66
# Chaperones and folding catalysts                 63
# Ribosome biogenesis in eukaryotes                55
# Glycolysis                                       53
# Spliceosome                                      52
# Glycan metabolism                                46
# Protein processing in endoplasmic reticulum      45
# Translation factors                              42
# Oxidative phosphorylation                        42
# RNA transport                                    40
# RNA degradation                                  36
# tRNA loading                                     36
# Proteasome                                       33
# Peptidases                                       32
# Carbohydrate metabolism                          32
# MAPK signaling pathway                           30
# Cytoskeleton proteins                            30
# Purine metabolism                                30
# Basal transcription factors                      28
# RNA polymerase                                   28
# Transcription factors                            27
# TCA cycle and anaplerotic enzymes                27
# Ubiquitin labeling                               27
# Cell wall                                        26
#                                                ...
# DNA repair and recombination proteins             9
# Regulation of actin cytoskeleton                  8
# Meiosis                                           6
# Regulation of autophagy                           5
# Sulfur relay system                               5
# Base excision repair                              4
# Butanoate metabolism                              3
# Pyruvate metabolism                               3
# Homologous recombination                          3
# Mismatch repair                                   3
# Biosynthesis of other secondary metabolites       3
# Nucleotide excision repair                        2
# ErbB signaling pathway                            2
# Carbon fixation in photosynthetic organisms       2
# Secretion system                                  2
# VEGF signaling pathway                            2
# Glycan binding proteins                           1
# Hippo signaling pathway                           1
# Non-homologous end-joining                        1
# G protein-coupled receptors                       1
# Cellular antigens                                 1
# Ion channels                                      1
# DNA replication                                   1
# SNAREs                                            1
# Methane metabolism                                1
# Protein kinases                                   1
# Two-component system                              1
# Calcium signaling pathway                         1
# Jak-STAT signaling pathway                        1
# mTOR signaling pathway                            1
# Name: Function, dtype: int64
