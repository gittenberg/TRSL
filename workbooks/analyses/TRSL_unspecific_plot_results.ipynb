# %% [markdown]
# # Plot results from unspecific TRSL model

# %%
import cPickle as pkl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %% [markdown]
# Recipe to unpickle objects according to http://stackoverflow.com/questions/2121874/python-pickling-after-changing-a-modules-directory:

# %%
import sys
from translation import MRNA

sys.modules['MRNA'] = MRNA

# %%
#proteome_model = pkl.load(open("/home/martin/git/TRSL/results/results_20170317_1542_0020s.p", "rb"))
proteome_model = pkl.load(open("/home/martin/git/TRSL/results/results_20170317_1608_10_ribosomes_0030s.p", 
                               "rb"))

# print proteome_model.keys()
# print proteome_model['timecourses'].keys()
print proteome_model['timecourses']['peptide_bonds']
# Out:
# [0, 0, 0, 0, 0, 0, 416, 416, 416, 416, 416, 416, 416, 416, 416, 416, 416, 416, 416, 416, 416, 416, 416, 416, 833, 833, 833, 833, 1249, 1666, 2083, 2083, 2083, 2083, 2083, 2083, 2083, 2083, 2083, 2083, 2083, 2083, 2083, 2083, 2501, 2501, 2919, 2919, 2919, 2919, 2919, 2919, 2919, 3336, 3336, 3336, 3336, 3336, 3336, 3336, 3336, 3336, 3336, 3336, 3754, 3754, 3754, 3754, 3754, 3754, 3754, 3754, 3754, 3754, 3754, 3754, 3754, 3754, 3754, 3754, 4170, 4170, 4170, 4170, 4170, 4170, 4170, 4170, 4170, 4170, 4170, 4170, 4170, 4170, 4587, 5004, 5004, 5004, 5004, 5004, 5004, 5420, 5420, 5420, 5836, 5836, 5836, 5836, 5836, 5836, 5836, 5836, 5836, 5836, 5836, 6255, 6255, 6255, 6671, 6671, 6671, 6671, 6671, 6671, 6671, 6671, 6671, 6671, 6671, 6671, 6671, 6671, 6671, 6671, 6671, 6671, 7087, 7087, 7087, 7087, 7087, 7087, 7087, 7087, 7087, 7087, 7087, 7087, 7087, 7087]

# %%
timerange = proteome_model['timerange']
fieldnames = ["peptide_bonds", "tRNA_bound", "tRNA_free", "AMP", "GDP"]

# %%
for key in fieldnames:
    fig =  plt.figure()                

    print key
    #print proteome_model['timecourses'][key]
    plt.plot(timerange, proteome_model['timecourses'][key], 'r-')
    plt.ylim(ymin=0)
    plt.title(key)
# Out:
# peptide_bonds
# tRNA_bound
# tRNA_free
# AMP
# GDP
