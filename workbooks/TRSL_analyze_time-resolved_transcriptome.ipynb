# %% [markdown]
# ##Analyze time-resolved transcriptome data

# %%
import csv
import pandas as pd
import cPickle as pkl
# %matplotlib inline

from pygenome import sg

# %% [markdown]
# First we get all the systematic names from `yeastgenome.org`:

# %%
orf_genomic_dict = pkl.load(open("../parameters/orf_coding.p"))
len(orf_genomic_dict)
# Out:
# 5917

# %% [markdown]
# Some appear to be missing (expected were >6000).

# %%
filename = "../data/nostress_WT_R1.csv"
transcripts = pd.DataFrame()

with open(filename, mode='r') as infile:
    reader = csv.reader(infile, delimiter=',')
    times = [int(float(val)) for val in reader.next()[1:]]
    ntimes = len(times)
    for rows in reader:
        try:
            # convert to systematic names
            colname = rows[0] if rows[0] in orf_genomic_dict else sg.systematic_name(rows[0])
            transcript_values = pd.Series(data=[float(rows[i]) for i in range(2, ntimes + 1)])  # the time point -1 is not needed
            transcripts[colname] = transcript_values
        except:
            pass

# %% [markdown]
# Create row labels (time points):

# %%
transcripts.index = times[1:]

# %%
print len(transcripts.columns)
# Out:
# 5795

# %% [markdown]
# Normalize to 100% for every time point:

# %%
transcripts_norm = (transcripts.T / transcripts.sum(axis=1)).T

# %%
transcripts_norm
# Out:
#       YAL001C   YAL002W   YAL003W   YAL005C   YAL007C   YAL008W   YAL009W  \
# 0    0.000022  0.000028  0.001257  0.002140  0.000100  0.000050  0.000039
# 10   0.000032  0.000026  0.001162  0.001507  0.000149  0.000090  0.000045
# 15   0.000024  0.000024  0.001246  0.001143  0.000122  0.000063  0.000049
# 20   0.000030  0.000021  0.001238  0.001207  0.000115  0.000043  0.000051
# 25   0.000031  0.000025  0.001406  0.001169  0.000107  0.000063  0.000088
# 30   0.000026  0.000031  0.001409  0.001306  0.000118  0.000035  0.000065
# 35   0.000013  0.000038  0.001463  0.001387  0.000110  0.000034  0.000051
# 40   0.000031  0.000023  0.001012  0.001520  0.000077  0.000023  0.000100
# 45   0.000026  0.000026  0.001730  0.001256  0.000051  0.000032  0.000051
# 50   0.000018  0.000022  0.001383  0.001559  0.000053  0.000040  0.000075
# 55   0.000035  0.000020  0.001446  0.001458  0.000081  0.000015  0.000030
# 60   0.000036  0.000027  0.001430  0.001367  0.000041  0.000032  0.000091
# 70   0.000018  0.000024  0.001347  0.001267  0.000115  0.000042  0.000054
# 80   0.000042  0.000013  0.001360  0.001363  0.000121  0.000038  0.000075
# 90   0.000025  0.000017  0.001487  0.001634  0.000104  0.000062  0.000046
# 100  0.000025  0.000012  0.001599  0.001759  0.000090  0.000029  0.000074
# 110  0.000024  0.000033  0.001500  0.001803  0.000104  0.000019  0.000062
# 120  0.000039  0.000012  0.001143  0.001942  0.000097  0.000047  0.000047
# 130  0.000022  0.000022  0.001227  0.001631  0.000122  0.000044  0.000065
# 140  0.000015  0.000015  0.001107  0.001680  0.000112  0.000020  0.000066
# 150  0.000036  0.000016  0.001366  0.002097  0.000097  0.000053  0.000069
#
#       YAL010C   YAL011W   YAL012W   YAL013W   YAL014C   YAL015C   YAL016W  \
# 120  0.000082  0.000000  0.000043  0.000082  0.000027  0.000167 ...
# 130  0.000057  0.000000  0.000035  0.000079  0.000009  0.000170 ...
# 140  0.000061  0.000000  0.000061  0.000112  0.000025  0.000157 ...
# 150  0.000045  0.000000  0.000028  0.000065  0.000041  0.000077 ...
#
# [21 rows x 5795 columns]

# %% [markdown]
# Calculate measure of transcriptional load:

# %% [markdown]
# ####Attempt 1: by weighting transcript abundance with transcript length

# %%
orf_lengths = {prot: len(orf_genomic_dict[prot]) for prot in orf_genomic_dict}

# %%
tr_load_l = pd.DataFrame()

for column in transcripts_norm:
    tr_load_l[column] = transcripts_norm[column] * orf_lengths[column]

# %%
tr_load_l.ix[:25, :10]
# Out:
#      YAL001C   YAL002W   YAL003W   YAL005C   YAL007C   YAL008W   YAL009W  \
# 0   0.077171  0.105936  0.780834  4.127169  0.064608  0.029762  0.030244
# 10  0.112465  0.098806  0.721867  2.906112  0.096249  0.053975  0.035260
# 15  0.084762  0.093084  0.773761  2.205027  0.078848  0.037774  0.037964
# 20  0.103758  0.081390  0.769050  2.329194  0.074458  0.025406  0.039833
# 25  0.109273  0.096002  0.872825  2.255849  0.069121  0.037459  0.068519
#
#      YAL010C   YAL011W   YAL012W
# 0   0.024627  0.072817  1.496561
# 10  0.009571  0.060640  1.874897
# 15  0.021639  0.073124  1.747577
# 20  0.012614  0.063937  1.573413
# 25  0.009299  0.023567  1.345812
#
# [5 rows x 10 columns]

# %%
tr_load_l.sum(axis=1).plot()

# %% [markdown]
# ####Attempt 2: by weighting transcript abundance with initiation probability

# %%
init_probs_plotkin = pkl.load(open('../parameters/init_rates_plotkin.p'))

# %%
tr_load_i = pd.DataFrame()

for column in transcripts_norm:
    if column in init_rates_plotkin:
        tr_load_i[column] = transcripts_norm[column] * init_probs_plotkin[column]

# %%
tr_load_i.ix[:25, :10]
# Out:
#          YAL001C       YAL002W       YAL003W       YAL007C       YAL008W  \
# 0   1.684397e-11  1.064421e-11  7.522649e-09  2.017337e-10  1.507733e-10
# 10  2.454743e-11  9.927850e-12  6.954551e-09  3.005284e-10  2.734397e-10
# 15  1.850071e-11  9.352930e-12  7.454508e-09  2.461955e-10  1.913636e-10
# 20  2.264701e-11  8.177905e-12  7.409117e-09  2.324868e-10  1.287094e-10
# 25  2.385067e-11  9.646056e-12  8.408900e-09  2.158247e-10  1.897702e-10
#
#          YAL009W       YAL010C       YAL011W       YAL012W       YAL013W
# 0   3.036259e-11  1.700403e-11  3.775237e-11  5.673566e-09  1.083168e-10
# 10  3.539895e-11  6.608186e-12  3.143894e-11  7.107863e-09  8.418921e-11
# 15  3.811315e-11  1.494122e-11  3.791144e-11  6.625186e-09  1.480525e-10
# 20  3.998992e-11  8.709417e-12  3.314856e-11  5.964917e-09  2.126718e-10
# 25  6.878836e-11  6.420617e-12  1.221863e-11  5.102066e-09  1.226993e-10
#
# [5 rows x 10 columns]

# %%
len(tr_load_i.columns)
# Out:
# 4682

# %%
tr_load_i.sum(axis=1).plot()
